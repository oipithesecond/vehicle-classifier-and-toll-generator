# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.2 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/Trucks_YOLO.zip -d /content/datasets
# Out:
# Archive:  /content/drive/MyDrive/Trucks_YOLO.zip
#    creating: /content/datasets/Trucks_YOLO/
#   inflating: /content/datasets/Trucks_YOLO/dataset.yaml
#    creating: /content/datasets/Trucks_YOLO/train/
#    creating: /content/datasets/Trucks_YOLO/train/images/
#   inflating: /content/datasets/Trucks_YOLO/train/images/20160927100754-550_color-_ROI-1_-15.jpg
#   inflating: /content/datasets/Trucks_YOLO/train/images/20160927100754-550_color-_ROI-1_-17.jpg
#   inflating: /content/datasets/Trucks_YOLO/train/images/20160927100754-550_color-_ROI-1_-19.jpg
#   inflating: /content/datasets/Trucks_YOLO/train/images/20160927100754-550_color-_ROI-1_-21.jpg
#   inflating: /content/datasets/Trucks_YOLO/train/images/20160927100754-550_color-_ROI-1_-8.jpg
#   inflating: /content/datasets/Trucks_YOLO/train/images/20160927102749_color-_ROI-1_-1.jpg
#   inflating: /content/datasets/Trucks_YOLO/train/images/20160927102749_color-_ROI-1_-10.jpg
# ...

# %%
# %%writefile /content/datasets/Trucks_YOLO/data.yaml
#
# path: /content/datasets/Trucks_YOLO  # Path to the dataset root
# train: train/images                  # Path to training images
# val: val/images                    # Path to validation images
#
# nc: 1
# names: ['axle']
# Out:
# Writing /content/datasets/Trucks_YOLO/data.yaml

# %%
# !yolo task=detect mode=train \
model='yolov10s.pt' \
data='/content/datasets/Trucks_YOLO/data.yaml' \
epochs=50 \
batch=16 \
imgsz=640 \
project='/content/drive/MyDrive/yolo_runs' \
name='yolov10s_trucks_training'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
